# %% [markdown]
# # FAS USDA - OILSEEDs database

# %% [markdown]
# https://apps.fas.usda.gov/psdonline/app/index.html#/app/downloads
#
# Dados de producao USDA:
#
# https://www.ers.usda.gov/data-products/oil-crops-yearbook/oil-crops-yearbook/#Soy%20and%20Soybean%20Products
#
# Worldwide production:
# https://ourworldindata.org/soy
#
# IBGE:
#
# https://www.ibge.gov.br/en/statistics/economic/agriculture-forestry-and-fishing/17174-systematic-survey-of-agricultural-production.html?=&t=resultados

# %%
import pandas as pd

# %%
fas_usda_data = pd.read_csv("../raw_data/fas_usda_oilseeds.csv")

# %%
fas_usda_data.head(20)
# Out:
#     Commodity_Code Commodity_Description Country_Code Country_Name  \
# 0           813700           Meal, Copra           AS    Australia
# 1           813700           Meal, Copra           AS    Australia
# 2           813700           Meal, Copra           AS    Australia
# 3           813700           Meal, Copra           AS    Australia
# 4           813700           Meal, Copra           AS    Australia
# 5           813700           Meal, Copra           AS    Australia
# 6           813700           Meal, Copra           AS    Australia
# 7           813700           Meal, Copra           AS    Australia
# 8           813700           Meal, Copra           AS    Australia
# 9           813700           Meal, Copra           AS    Australia
# 10          813700           Meal, Copra           AS    Australia
# 11          813700           Meal, Copra           AS    Australia
# 12          813700           Meal, Copra           AS    Australia
# ...

# %%
fas_usda_data['Attribute_Description'].unique()
# Out:
# array(['Beginning Stocks', 'Crush', 'Domestic Consumption',
#        'Ending Stocks', 'Exports', 'Extr. Rate, 999.9999',
#        'Feed Waste Dom. Cons.', 'Food Use Dom. Cons.', 'Imports',
#        'Industrial Dom. Cons.', 'Production', 'SME', 'Total Distribution',
#        'Total Supply', 'Catch For Reduction', 'Area Harvested', 'Yield',
#        'Seed to Lint Ratio'], dtype=object)

# %%
fas_data = fas_usda_data[(fas_usda_data['Commodity_Description'] == "Meal, Soybean") |
                         (fas_usda_data['Commodity_Description'] == "Oil, Soybean") |
                         (fas_usda_data['Commodity_Description'] == "Meal, Soybean (Local)")|
                         (fas_usda_data['Commodity_Description'] == "Oil, Soybean (Local)")]

# %%
fas_data = fas_data[fas_data['Attribute_Description'] == "Production"]

# %%
fas_data['Attribute_Description'].unique()
# Out:
# array(['Production'], dtype=object)

# %%
fas_data[(fas_data["Country_Code"]=="BR") & (fas_data["Commodity_Description"]=="Meal, Soybean")]
# Out:
#         Commodity_Code Commodity_Description Country_Code Country_Name  \
# 161724          813100         Meal, Soybean           BR       Brazil
# 161738          813100         Meal, Soybean           BR       Brazil
# 161752          813100         Meal, Soybean           BR       Brazil
# 161766          813100         Meal, Soybean           BR       Brazil
# 161780          813100         Meal, Soybean           BR       Brazil
# 161794          813100         Meal, Soybean           BR       Brazil
# 161808          813100         Meal, Soybean           BR       Brazil
# 161822          813100         Meal, Soybean           BR       Brazil
# 161836          813100         Meal, Soybean           BR       Brazil
# 161850          813100         Meal, Soybean           BR       Brazil
# 161864          813100         Meal, Soybean           BR       Brazil
# 161878          813100         Meal, Soybean           BR       Brazil
# ...

# %%
fas_data = fas_usda_data[(fas_usda_data['Commodity_Description'] == "Meal, Soybean") |
                         (fas_usda_data['Commodity_Description'] == "Oil, Soybean") |
                         (fas_usda_data['Commodity_Description'] == "Meal, Soybean (Local)")|
                         (fas_usda_data['Commodity_Description'] == "Oil, Soybean (Local)")]
